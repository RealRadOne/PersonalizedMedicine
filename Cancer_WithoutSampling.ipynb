# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, accuracy_score
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.ensemble import VotingClassifier

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/cancer-diagnosis/training_text
# /kaggle/input/cancer-diagnosis/training_variants
# /kaggle/input/cancertreatment/stage2_test_text.csv
# /kaggle/input/cancertreatment/test_text
# /kaggle/input/cancertreatment/stage_2_private_solution.csv
# /kaggle/input/cancertreatment/stage2_sample_submission.csv
# /kaggle/input/cancertreatment/stage1_solution_filtered.csv
# /kaggle/input/cancertreatment/test_variants
# /kaggle/input/cancertreatment/stage2_test_variants.csv

# %%
training_text = pd.read_csv("../input/cancer-diagnosis/training_text",sep="\|\|", header=None, skiprows=1, names=["ID","Text"])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
training_text.head(5)
# Out:
#    ID                                               Text
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %%
training_text.shape
# Out:
# (3321, 2)

# %%
training_variants = pd.read_csv("../input/cancer-diagnosis/training_variants")

# %%
training_variants.head(5)
# Out:
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %%
training_variants.shape
# Out:
# (3321, 4)

# %%
#Merging variants and text on ID

# %%
training_merge = training_variants.merge(training_text,left_on="ID",right_on="ID")

# %%
training_merge.head(5)
#Now we have the data
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 Text
# 0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   Abstract Background  Non-small cell lung canc...
# 2   Abstract Background  Non-small cell lung canc...
# 3  Recent evidence has demonstrated that acquired...
# 4  Oncogenic mutations in the monomeric Casitas B...

# %%
training_merge.shape
# Out:
# (3321, 5)

# %%
test_text = pd.read_csv("../input/cancertreatment/stage2_test_text.csv",sep="\|\|", header=None, skiprows=1, names=["ID","Text"])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
test_text.shape
# Out:
# (986, 2)

# %%
test_variants = pd.read_csv("../input/cancertreatment/stage2_test_variants.csv")

# %%
test_variants.shape
# Out:
# (986, 3)

# %%
test_merge = test_variants.merge(test_text,left_on="ID",right_on="ID")

# %%
# Let's understand the type of values present in each column of our dataframe 'train_merge' dataframe.
test_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 986 entries, 0 to 985
# Data columns (total 4 columns):
# ID           986 non-null int64
# Gene         986 non-null object
# Variation    986 non-null object
# Text         986 non-null object
# dtypes: int64(1), object(3)
# memory usage: 38.5+ KB

# %%
training_merge.describe(include='all')
# Out:
#                  ID   Gene             Variation        Class  \
# count   3321.000000   3321                  3321  3321.000000
# unique          NaN    264                  2996          NaN
# top             NaN  BRCA1  Truncating Mutations          NaN
# freq            NaN    264                    93          NaN
# mean    1660.000000    NaN                   NaN     4.365854
# std      958.834449    NaN                   NaN     2.309781
# min        0.000000    NaN                   NaN     1.000000
# 25%      830.000000    NaN                   NaN     2.000000
# 50%     1660.000000    NaN                   NaN     4.000000
# 75%     2490.000000    NaN                   NaN     7.000000
# max     3320.000000    NaN                   NaN     9.000000
#
#                                                      Text
# count                                                3316
# unique                                               1920
# top     The PTEN (phosphatase and tensin homolog) phos...
# freq                                                   53
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
training_merge.isnull().sum()
# Out:
# ID           0
# Gene         0
# Variation    0
# Class        0
# Text         5
# dtype: int64

# %%
training_merge.columns
# Out:
# Index(['ID', 'Gene', 'Variation', 'Class', 'Text'], dtype='object')

# %%
training_merge["Text_num_words"] = training_merge["Text"].apply(lambda x: len(str(x).split()) )
training_merge["Text_num_chars"] = training_merge["Text"].apply(lambda x: len(str(x)) )

# %%
training_merge['Variation'].describe()
# Out:
# count                     3321
# unique                    2996
# top       Truncating Mutations
# freq                        93
# Name: Variation, dtype: object

# %%
training_merge['Gene'].describe()
# Out:
# count      3321
# unique      264
# top       BRCA1
# freq        264
# Name: Gene, dtype: object

# %%
from collections import Counter
# Import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
# Import word_tokenize
from nltk.tokenize import word_tokenize
# Import stopwords
from nltk.corpus import stopwords
# Import string
import string
#Importing

# %%
#Tokenzing-splitting up a larger body of text into smaller lines, words or even creating words

# %%
#imputing gene row value to null data of text rows as for all other columns, Gene values are present in Text data
training_merge['Text'] = training_merge.apply(lambda row: row['Gene'] if pd.isnull(row['Text']) else row['Text'],axis=1)

# %%
training_merge.isnull().sum()
# Out:
# ID                0
# Gene              0
# Variation         0
# Class             0
# Text              0
# Text_num_words    0
# Text_num_chars    0
# dtype: int64

# %%
#imputing gene row value to null data of text rows as for all other columns, Gene values are present in Text data
test_merge['Text'] = test_merge.apply(lambda row: row['Gene'] if pd.isnull(row['Text']) else row['Text'],axis=1)

# %%
mincl=[3,5,6,8,9]
maxcl=[1,2,4,7]

# %%
dfA=training_merge[training_merge['Class'].isin(mincl)]
dfB=training_merge[training_merge['Class'].isin(maxcl)]

# %%
dfA.head(5)
# Out:
#     ID Gene Variation  Class  \
# 3    3  CBL     N454D      3
# 6    6  CBL     V430M      5
# 14  14  CBL     P428L      5
# 18  18  CBL     M374V      5
# 20  20  CBL      H94Y      6
#
#                                                  Text  Text_num_words  \
# 3   Recent evidence has demonstrated that acquired...            5572
# 6   Oncogenic mutations in the monomeric Casitas B...            6202
# 14  Oncogenic mutations in the monomeric Casitas B...            6202
# 18  Oncogenic mutations in the monomeric Casitas B...            6202
# 20   Abstract Background  Non-small cell lung canc...           11958
#
#     Text_num_chars
# 3            36238
# 6            41308
# 14           41308
# 18           41308
# 20           78000

# %%
dfA.describe()
# Out:
#                 ID       Class  Text_num_words  Text_num_chars
# count   662.000000  662.000000      662.000000      662.000000
# mean   1957.531722    5.456193     7666.942598    50961.948640
# std     874.612086    1.378586     4694.537482    31233.168057
# min       3.000000    3.000000        1.000000        3.000000
# 25%    1311.500000    5.000000     4951.750000    33028.000000
# 50%    2289.000000    5.500000     6463.000000    43019.000000
# 75%    2664.500000    6.000000     8812.000000    58319.000000
# max    3314.000000    9.000000    45177.000000   297907.000000

# %%
dfB.describe()
# Out:
#                 ID        Class  Text_num_words  Text_num_chars
# count  2659.000000  2659.000000     2659.000000     2659.000000
# mean   1585.924784     4.094396    10020.205716    66766.388116
# std     964.662185     2.412760     8388.648466    55764.626380
# min       0.000000     1.000000        1.000000        3.000000
# 25%     748.500000     2.000000     4715.000000    31199.500000
# 50%    1545.000000     4.000000     7082.000000    46804.000000
# 75%    2331.500000     7.000000    12935.000000    85401.500000
# max    3320.000000     7.000000    76782.000000   523393.000000

# %%
#taking class column as dependent variable ie which needs to be find out from all other columns in our data
ym=training_merge.Class
yA=dfA.Class
yB=dfB.Class

# %%
X_A=dfA[["Text","Variation","Gene"]]
X_B=dfB[["Text","Variation","Gene"]]
X_m=training_merge[["Text","Variation","Gene"]]

# %%
X_A.head()
# Out:
#                                                  Text Variation Gene
# 3   Recent evidence has demonstrated that acquired...     N454D  CBL
# 6   Oncogenic mutations in the monomeric Casitas B...     V430M  CBL
# 14  Oncogenic mutations in the monomeric Casitas B...     P428L  CBL
# 18  Oncogenic mutations in the monomeric Casitas B...     M374V  CBL
# 20   Abstract Background  Non-small cell lung canc...      H94Y  CBL

# %%
X_B.head()
# Out:
#                                                 Text             Variation  \
# 0  Cyclin-dependent kinases (CDKs) regulate a var...  Truncating Mutations
# 1   Abstract Background  Non-small cell lung canc...                 W802*
# 2   Abstract Background  Non-small cell lung canc...                 Q249E
# 4  Oncogenic mutations in the monomeric Casitas B...                 L399V
# 5  Oncogenic mutations in the monomeric Casitas B...                 V391I
#
#      Gene
# 0  FAM58A
# 1     CBL
# 2     CBL
# 4     CBL
# 5     CBL

# %%
# Definig vectorizing object for Text column
vect_text= CountVectorizer(stop_words ='english')

#Defining vectorizing object for Variation column
vect_variation= CountVectorizer(stop_words ='english')

##Defining vectorizing object for Gene column
gene_variation= CountVectorizer(stop_words ='english')

# %%
#vectorizing  for Text column which gives the count of repeated words for each row for both the dataframes
vect_text.fit(X_A["Text"])
vect_text.fit(X_B["Text"])
vect_text.fit(X_m["Text"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
#vectorizing for Variation column  which gives the count of repeated words for each row
vect_variation.fit(X_A["Variation"])
vect_variation.fit(X_B["Variation"])
vect_variation.fit(X_m["Variation"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
gene_variation.fit(X_A["Gene"])
gene_variation.fit(X_B["Gene"])
gene_variation.fit(X_m["Gene"])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words='english',
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
len(vect_text.vocabulary_)
# Out:
# 155436

# %%
len(vect_variation.vocabulary_)
# Out:
# 3018

# %%
len(gene_variation.vocabulary_)
# Out:
# 263

# %%
vect_text.vocabulary_
# Out:
# {'cyclin': 46416,
#  'dependent': 49831,
#  'kinases': 84518,
#  'cdks': 39059,
#  'regulate': 122979,
#  'variety': 149216,
#  'fundamental': 63308,
#  'cellular': 39396,
#  'processes': 116246,
#  'cdk10': 38984,
#  'stands': 134564,
#  'orphan': 106331,
#  'activating': 21738,
#  'identified': 77289,
#  'kinase': 84487,
#  'activity': 21828,
#  'revealed': 124400,
#  'previous': 115708,
#  'work': 152130,
#  'shown': 131283,
#  'silencing': 131834,
#  'increases': 79006,
#  'ets2': 58046,
#  'ets': 58044,
#  'erythroblastosis': 57693,
#  'virus': 149982,
#  'e26': 54074,
#  'oncogene': 105646,
#  'homolog': 74768,
#  'driven': 52980,
#  'activation': 21744,
#  'mapk': 92253,
#  'pathway': 109370,
#  'confers': 43377,
#  'tamoxifen': 138590,
#  'resistance': 123868,
#  'breast': 33867,
#  'cancer': 36529,
#  'cells': 39240,
#  'precise': 115237,
#  'mechanisms': 93442,
#  'modulates': 96818,
#  'generally': 66518,
#  'functions': 63287,
#  'remain': 123237,
#  'elusive': 56114,
#  'demonstrate': 49617,
#  'identifying': 77318,
#  'product': 116305,
#  'fam58a': 60058,
#  'mutations': 98728,
#  'cause': 37764,
#  'star': 134586,
#  'syndrome': 137047,
#  'human': 75751,
#  'developmental': 50425,
#  'anomaly': 26011,
#  'features': 60546,
#  'include': 78935,
#  'toe': 142523,
#  'syndactyly': 137042,
#  'telecanthus': 139636,
#  'anogenital': 26001,
#  'renal': 123310,
#  'malformations': 91881,
#  'associated': 28658,
#  'mutants': 98615,
#  'unable': 146680,
#  'interact': 80120,
#  'phenocopies': 111831,
#  'increasing': 79007,
#  'raf': 121199,
#  'conferring': 43376,
#  'phosphorylates': 112273,
#  'vitro': 150068,
#  'positively': 114564,
#  'controls': 43890,
#  'degradation': 49171,
#  'proteasome': 116867,
#  'protein': 116888,
#  'levels': 88294,
#  'increased': 78999,
#  'derived': 49974,
#  'patient': 109452,
#  'increase': 78997,
#  'attributable': 29379,
#  'decreased': 48989,
#  'altogether': 24598,
#  'results': 124111,
#  'reveal': 124398,
#  'additional': 22080,
#  'regulatory': 123012,
#  'mechanism': 93428,
#  'plays': 113381,
#  'key': 84250,
#  'roles': 125396,
#  'development': 50384,
#  'shed': 130977,
#  'light': 88602,
#  'molecular': 96910,
#  'underlying': 146900,
#  'play': 113376,
#  'pivotal': 113009,
#  'role': 125391,
#  'control': 43866,
#  'number': 104367,
#  'genome': 66689,
#  'contains': 43738,
#  '21': 6655,
#  'genes': 66544,
#  'encoding': 56429,
#  'proteins': 116949,
#  'considered': 43591,
#  'members': 93986,
#  'cdk': 38982,
#  'family': 60099,
#  'owing': 107052,
#  'sequence': 129928,
#  'similarity': 131891,
#  'bona': 33054,
#  'fide': 61072,
#  'known': 84999,
#  'activated': 21724,
#  'cyclins': 46430,
#  'discovered': 51435,
#  '20': 6210,
#  'ago': 23225,
#  'remains': 123245,
#  'partner': 109170,
#  'knowledge': 84996,
#  'gap': 65206,
#  'largely': 87177,
#  'impeded': 78630,
#  'exploration': 58899,
#  'biological': 32193,
#  'act': 21633,
#  'positive': 114558,
#  'cell': 39184,
#  'cycle': 46391,
#  'regulator': 123004,
#  'tumor': 145119,
#  'suppressor': 136488,
#  'interacts': 80162,
#  'transcription': 143247,
#  'factor': 59901,
#  'inhibits': 79587,
#  'transcriptional': 143271,
#  'unknown': 147210,
#  'knockdown': 84976,
#  'derepresses': 49955,
#  'expression': 58979,
#  'activates': 21736,
#  'induces': 79216,
#  'mcf7': 93074,
#  'deorphanize': 49745,
#  'binding': 31996,
#  'gene': 66387,
#  'predict': 115297,
#  'absence': 20943,
#  'truncation': 144399,
#  'heterozygous': 73481,
#  'females': 60635,
#  '10': 1391,
#  'pathogenesis': 109306,
#  'recombinant': 122470,
#  'heterodimer': 73389,
#  'active': 21807,
#  'phospho': 112134,
#  'erk': 57521,
#  'inducing': 79224,
#  'estrogen': 57935,
#  'receptor': 122349,
#  'er': 57352,
#  'phosphorylation': 112275,
#  'neighboring': 101019,
#  'serines': 130385,
#  'finally': 61443,
#  'detect': 50258,
#  'level': 88286,
#  'observed': 104728,
#  'sectionnext': 129431,
#  'sectionresultsa': 129436,
#  'yeast': 153820,
#  'hybrid': 75958,
#  'y2h': 153211,
#  'screen': 129193,
#  'unveiled': 147462,
#  'interaction': 80128,
#  'signal': 131634,
#  'mouse': 97527,
#  'terminal': 139851,
#  'half': 71939,
#  'presents': 115597,
#  'strong': 135393,
#  'homology': 74780,
#  'proposed': 116783,
#  '11': 1980,
#  'performed': 110853,
#  'mating': 92710,
#  'assays': 28563,
#  'determine': 50311,
#  'fig': 61092,
#  'longest': 89560,
#  'isoform': 81287,
#  'p1': 107210,
#  'expressed': 58954,
#  'bait': 30391,
#  'produced': 116294,
#  'phenotype': 111855,
#  'length': 87761,
#  'prey': 115777,
#  'detectable': 50260,
#  'd1': 46880,
#  'p21': 107500,
#  'cip1': 41263,
#  'cdi1': 38978,
#  'kap': 83739,
#  'partners': 109175,
#  '1b': 5667,
#  'cdk1': 38983,
#  'cdk3': 38999,
#  'signals': 131730,
#  'albeit': 23953,
#  'notably': 103584,
#  'weaker': 151138,
#  'respectively': 123952,
#  's1a': 126903,
#  'tested': 139936,
#  'different': 50905,
#  'isoforms': 81292,
#  'originating': 106274,
#  'alternative': 24577,
#  'splicing': 133907,
#  'truncated': 144395,
#  'corresponding': 44220,
#  'hypothetical': 76472,
#  'products': 116319,
#  'mutated': 98641,
#  'patients': 109462,
#  'shorter': 131246,
#  'phenotypes': 111887,
#  'new': 101531,
#  'window': 151762,
#  'download': 52716,
#  'pptfig': 114996,
#  'form': 62347,
#  'complex': 43014,
#  'schematic': 128820,
#  'representation': 123636,
#  'analyzed': 25270,
#  'amino': 24808,
#  'acid': 21488,
#  'numbers': 104380,
#  'indicated': 79120,
#  'black': 32562,
#  'boxes': 33339,
#  'indicate': 79119,
#  'internal': 80323,
#  'deletions': 49395,
#  'red': 122631,
#  'box': 33333,
#  'indicates': 79122,
#  'differing': 50974,
#  'compared': 42910,
#  'assay': 28531,
#  'set': 130478,
#  'baits': 30392,
#  'fusion': 63403,
#  'lexa': 88348,
#  'dna': 52131,
#  'domain': 52415,
#  'interacting': 80125,
#  'preys': 115778,
#  'b42': 30123,
#  'activator': 21799,
#  'peg202': 110578,
#  'pjg4': 113047,
#  'plasmids': 113307,
#  'expressing': 58971,
#  'lacz': 86876,
#  'used': 147727,
#  'reporter': 123592,
#  'blue': 32793,
#  'indicative': 79131,
#  'region': 122904,
#  'assayed': 28554,
#  'western': 151415,
#  'blot': 32765,
#  'analysis': 25180,
#  'myc': 99046,
#  'wt': 152280,
#  'kd': 84029,
#  'cycm': 46466,
#  'v5': 148354,
#  '6his': 15927,
#  'transfected': 143350,
#  'hek293': 72835,
#  'immunoprecipitates': 78502,
#  'obtained': 104766,
#  'using': 147756,
#  'anti': 26105,
#  'antibody': 26143,
#  'inputs': 79773,
#  'correspond': 44215,
#  'μg': 155355,
#  'total': 142874,
#  'lysates': 90698,
#  'coexpressing': 42294,
#  'goat': 69034,
#  'input': 79771,
#  'corresponds': 44226,
#  '30': 9230,
#  'lower': 89724,
#  'band': 30507,
#  'doublet': 52670,
#  'upper': 147559,
#  'panel': 108763,
#  'comigrates': 42772,
#  'exogenously': 58678,
#  'untagged': 147419,
#  'endogenous': 56518,
#  'nonspecific': 103354,
#  'demonstrated': 49618,
#  'insensitivity': 79839,
#  'overexpression': 106904,
#  'seen': 129487,
#  'left': 87647,
#  'lane': 87074,
#  's2b': 127113,
#  'experiment': 58841,
#  'longer': 89559,
#  'gel': 66320,
#  'migration': 95550,
#  's1d': 126906,
#  'examined': 58483,
#  'ability': 20805,
#  'wild': 151683,
#  'type': 145585,
#  'dead': 48767,
#  'mutant': 98581,
#  'bearing': 31107,
#  'd181a': 47157,
#  'substitution': 135900,
#  'abolishes': 20890,
#  'atp': 29181,
#  '12': 2484,
#  'embryonic': 56212,
#  'kidney': 84399,
#  'line': 88748,
#  'significantly': 131775,
#  'coexpression': 42295,
#  'lesser': 87867,
#  'extent': 59081,
#  '1d': 5721,
#  'immunoprecipitated': 78500,
#  'detected': 50263,
#  'presence': 115572,
#  'coexpressed': 42293,
#  'pair': 108552,
#  'wise': 151809,
#  '1e': 5749,
#  'confirmed': 43403,
#  'observations': 104714,
#  'detecting': 50277,
#  's1b': 126904,
#  'experiments': 58851,
#  'lack': 86839,
#  'robust': 125300,
#  'p2': 107483,
#  's1c': 126905,
#  'immunoprecipitations': 78512,
#  'nontransfected': 103398,
#  'antibodies': 26133,
#  'cognate': 42326,
#  'blotting': 32772,
#  'readily': 122136,
#  '1f': 5765,
#  'confirm': 43397,
#  'physical': 112487,
#  'unveil': 147461,
#  'hypothesized': 76468,
#  'gst': 70189,
#  'strepii': 135294,
#  'insect': 79831,
#  'individually': 79174,
#  'combination': 42726,
#  'copurified': 44073,
#  'confirming': 43406,
#  'model': 96701,
#  '2a': 8758,
#  'purified': 118153,
#  'histone': 74190,
#  'h1': 71091,
#  'generic': 66538,
#  'substrate': 135919,
#  'investigated': 80749,
#  '1c': 5687,
#  '2b': 8799,
#  'glutathione': 68620,
#  'sepharose': 129877,
#  'matrix': 92727,
#  'capture': 36878,
#  'str': 135160,
#  'blots': 32769,
#  'middle': 95476,
#  'determined': 50312,
#  'autoradiography': 29689,
#  'added': 22066,
#  'amounts': 24947,
#  'visualized': 150037,
#  'coomassie': 44001,
#  'staining': 134500,
#  'activate': 21723,
#  'involved': 80799,
#  'aim': 23460,
#  'highly': 73806,
#  'specific': 133599,
#  'sirna': 132060,
#  'pools': 114410,
#  'mix': 96137,
#  'sirnas': 132068,
#  'low': 89707,
#  'final': 61437,
#  'concentration': 43242,
#  'nm': 102249,
#  'silenced': 131829,
#  'targets': 138729,
#  's2': 126922,
#  'interestingly': 80234,
#  'pool': 114403,
#  'caused': 37765,
#  'marked': 92416,
#  'decrease': 48987,
#  '3a': 11069,
#  'suggest': 136106,
#  'stabilizes': 134432,
#  'induced': 79210,
#  'mrna': 97731,
#  'phosphorylated': 112272,
#  'erk1': 57522,
#  'erk2': 57545,
#  's3b': 127276,
#  'similarly': 131893,
#  'expected': 58809,
#  'effects': 55310,
#  'sensitivity': 129800,
#  'similar': 131889,
#  'combined': 42740,
#  'did': 50828,
#  'result': 124101,
#  'higher': 73790,
#  'drug': 53032,
#  's3c': 127277,
#  'functional': 63265,
#  'negatively': 100984,
#  'regulates': 122983,
#  'response': 124007,
#  'mediated': 93539,
#  'quantification': 119262,
#  's3a': 127275,
#  'quantitative': 119283,
#  'rt': 126231,
#  'pcr': 109995,
#  '01': 492,
#  '001': 171,
#  'wished': 151814,
#  'explore': 58904,
#  'short': 131236,
#  'lived': 89061,
#  'degraded': 49190,
#  '13': 2943,
#  'straightforward': 135176,
#  'hypothesis': 76462,
#  'impact': 78605,
#  'flag': 61659,
#  's4a': 127415,
#  '4a': 12837,
#  'marginally': 92369,
#  'fluctuated': 61921,
#  's4b': 127417,
#  'tagged': 138415,
#  'dramatically': 52901,
#  '4b': 12869,
#  'excess': 58518,
#  'major': 91802,
#  'involves': 80807,
#  'treatment': 143782,
#  'inhibitor': 79527,
#  'mg132': 94914,
#  'rescued': 123757,
#  'stability': 134408,
#  'cotransfected': 44367,
#  'vectors': 149407,
#  'treated': 143775,
#  '16': 4126,
#  'proper': 116748,
#  'verified': 149603,
#  'quantifications': 119264,
#  's4': 127302,
#  'mass': 92583,
#  'spectrometry': 133677,
#  'existence': 58647,
#  'multiple': 98335,
#  'residues': 123842,
#  'positions': 114553,
#  '220': 6959,
#  '225': 7079,
#  'phosphodegron': 112151,
#  '14': 3344,
#  'figs': 61199,
#  's5': 127440,
#  's8': 127735,
#  'finding': 61454,
#  'ets2wt': 58050,
#  'ets2sasa': 58049,
#  'alanine': 23931,
#  'substitutions': 135908,
#  'sites': 132119,
#  'small': 132685,
#  'reproducible': 123685,
#  'significant': 131771,
#  's9': 127787,
#  'ser220': 130115,
#  'ser225': 130122,
#  'establish': 57881,
#  'direct': 51300,
#  'link': 88875,
#  'differ': 50894,
#  'contrary': 43846,
#  'ets2dbm': 58048,
#  'deletion': 49379,
#  'destruction': 50235,
#  'previously': 115710,
#  'apc': 26515,
#  'cdh1': 38968,
#  '4c': 12880,
#  'remained': 123241,
#  'insensitive': 79836,
#  '4d': 12900,
#  'directly': 51313,
#  'studied': 135487,
#  'lymphoblastoid': 90369,
#  'mutation': 98658,
#  '555': 13932,
#  '1g': 5782,
#  'predicted': 115300,
#  'aberrant': 20760,
#  'accordance': 21275,
#  'incomplete': 78960,
#  'skewing': 132282,
#  'chromosome': 41045,
#  'inactivation': 78824,
#  'preceding': 115214,
#  '5a': 14510,
#  's10a': 126679,
#  'showed': 131275,
#  '5b': 14531,
#  '5c': 14543,
#  'healthy': 72694,
#  'individual': 79164,
#  'vector': 149392,
#  'directing': 51304,
#  'revealing': 124406,
#  'endogenously': 56524,
#  's10b': 126680,
#  's10c': 126681,
#  'sectiondiscussionin': 129419,
#  'pregenomic': 115406,
#  'era': 57365,
#  'genetic': 66624,
#  'disease': 51510,
#  'far': 60180,
#  'closest': 41836,
#  'paralogs': 108961,
#  'cdk11': 38986,
#  '15': 3715,
#  'paralog': 108959,
#  's11': 126687,
#  'fact': 59898,
#  'robustly': 125302,
#  'suggests': 136118,
#  '17': 4478,
#  'important': 78699,
#  'regulating': 122984,
#  'relevance': 123197,
#  'supported': 136460,
#  'enhance': 56692,
#  'judged': 82598,
#  'reduced': 122693,
#  'subject': 135766,
#  'ubiquitin': 146278,
#  '18': 4909,
#  'protects': 116885,
#  'enhanced': 56693,
#  'independently': 79085,
#  'cdk8': 39016,
#  '19': 5258,
#  'uncover': 146834,
#  'demonstrating': 49626,
#  'named': 100086,
#  'sole': 133146,
#  'basis': 30750,
#  'genuine': 66790,
#  'produce': 116293,
#  'regardless': 122869,
#  'mrnas': 97746,
#  'undergo': 146881,
#  'nonsense': 103333,
#  'decay': 48893,
#  'suggested': 136107,
#  'rise': 124960,
#  'affected': 22607,
#  'exhibit': 58628,
#  'compromised': 43167,
#  'tissues': 142139,
#  'stages': 134481,
#  'interactor': 80160,
#  'exerted': 58612,
#  'fine': 61465,
#  'partially': 109138,
#  'achieved': 21472,
#  'findings': 61456,
#  'offer': 105088,
#  'explanation': 58878,
#  'reported': 123536,
#  'regulation': 122985,
#  'bring': 34005,
#  'evidence': 58304,
#  'noncanonical': 102929,
#  'trcp': 143761,
#  'dsmcpas': 53132,
#  'precede': 115208,
#  'proline': 116602,
#  'conform': 43419,
#  'usual': 147805,
#  'called': 36364,
#  'cdk7': 39015,
#  'belong': 31333,
#  'phosphorylate': 112271,
#  'motifs': 97469,
#  'non': 102870,
#  'directed': 51301,
#  'fashion': 60250,
#  'especially': 57840,
#  'context': 43771,
#  'docking': 52325,
#  'high': 73781,
#  'affinity': 22632,
#  'pointed': 113990,
#  'allow': 24397,
#  'atypical': 29424,
#  'players': 113379,
#  'including': 78941,
#  'cullin': 46070,
#  'ring': 124904,
#  'ligase': 88587,
#  'crl4': 44975,
#  'formal': 62356,
#  'identification': 77282,
#  'elucidation': 56109,
#  'concerted': 43267,
#  'action': 21712,
#  'ligases': 88590,
#  'require': 123716,
#  'studies': 135494,
#  'present': 115579,
#  'medical': 93552,
#  'implications': 78683,
#  '22': 6958,
#  'frequently': 62882,
#  'deregulated': 49943,
#  'cancers': 36648,
#  '23': 7239,
#  'second': 129388,
#  'contribute': 43856,
#  'understanding': 146936,
#  'causing': 37772,
#  'like': 88634,
#  'predictive': 115314,
#  'clinical': 41689,
#  'marker': 92420,
#  'hormone': 74914,
#  'therapy': 141181,
#  'erα': 57731,
#  'interesting': 80233,
#  'transgenic': 143442,
#  'mice': 95086,
#  'showing': 131281,
#  'twofold': 145518,
#  'severe': 130570,
#  'cranial': 44700,
#  'abnormalities': 20871,
#  '24': 7469,
#  'consequence': 43562,
#  'risk': 124966,
#  'develop': 50371,
#  'certain': 39646,
#  'types': 145614,
#  'various': 149218,
#  'models': 96734,
#  'copies': 44047,
#  'exist': 58640,
#  'dosage': 52613,
#  'repress': 123653,
#  'promote': 116652,
#  'growth': 69854,
#  'exerts': 58616,
#  'noncell': 102940,
#  'autonomous': 29639,
#  '25': 7721,
#  'intringuingly': 80629,
#  'diagnosed': 50650,
#  'nephroblastoma': 101159,
#  '26': 7966,
#  'facilitate': 59865,
#  'general': 66504,
#  'particular': 109155,
#  'division': 51927,
#  'suppressive': 136486,
#  'retardation': 124224,
#  'exhibited': 58629,
#  'strongly': 135399,
#  'proliferation': 116558,
#  'sectionmaterials': 129428,
#  'methodscloning': 94630,
#  'cdnas': 39078,
#  'plasmid': 113295,
#  'constructions': 43680,
#  'production': 116310,
#  'detailed': 50250,
#  'si': 131438,
#  'materials': 92683,
#  'methods': 94611,
#  'described': 50043,
#  '27': 8157,
#  'mammalian': 92006,
#  'cultures': 46111,
#  'transfections': 143359,
#  'grew': 69682,
#  'dmem': 52074,
#  'supplemented': 136444,
#  'vol': 150253,
#  'fbs': 60389,
#  'invitrogen': 80782,
#  'rpmi': 125727,
#  '1640': 4257,
#  'glutamax': 68604,
#  'lipofectamine': 88941,
#  '2000': 6212,
#  'rnaimax': 125163,
#  'jetprime': 82223,
#  'polyplus': 114283,
#  'combinations': 42733,
#  'according': 21277,
#  'manufacturers': 92191,
#  'instructions': 79983,
#  'electroporation': 55866,
#  'neon': 101113,
#  '32': 9682,
#  'transfection': 143356,
#  'μm': 155370,
#  'fisher': 61568,
#  'scientific': 129034,
#  'coimmunoprecipitation': 42382,
#  'collected': 42554,
#  'scraping': 129183,
#  'pbs': 109719,
#  'centrifugation': 39488,
#  'lysed': 90703,
#  'sonication': 133276,
#  'lysis': 90714,
#  'buffer': 34444,
#  'containing': 43727,
#  '60': 14744,
#  'mm': 96376,
#  'glycerophosphate': 68858,
#  'nitrophenylphosphate': 102155,
#  'morpholino': 97353,
#  'propanesulfonic': 116735,
#  'mops': 97254,
#  'ph': 111528,
#  'egta': 55548,
#  'mgcl2': 94962,
#  'na': 99872,
#  'vanadate': 149072,
#  'naf': 99958,
#  '1mm': 5908,
#  'phenylphosphate': 111941,
#  'nonidet': 103124,
#  '40': 11448,
#  'protease': 116863,
#  'mixture': 96147,
#  'roche': 125311,
#  'spun': 134104,
#  'min': 95695,
#  '000': 1,
#  'supernatants': 136363,
#  'content': 43761,
#  'bradford': 33506,
#  'immunoprecipitation': 78508,
#  '500': 13136,
#  'precleared': 115245,
#  'μl': 155365,
#  'agarose': 22871,
#  'beads': 31088,
#  'incubated': 79021,
#  'rotating': 125565,
#  'wheel': 151486,
#  'washed': 150968,
#  'times': 142034,
#  'bead': 31082,
#  '50': 13135,
#  'tris': 144113,
#  '250': 7722,
#  'nacl': 99933,
#  'edta': 55193,
#  'coktail': 42424,
#  'sample': 128123,
#  'pellets': 110634,
#  'heat': 72708,
#  'denatured': 49649,
#  'ran': 121413,
#  'samples': 128141,
#  'bis': 32439,
#  'sds': 129313,
#  'page': 108508,
#  'transferred': 143371,
#  'hybond': 75954,
#  'nitrocellulose': 102147,
#  'membranes': 94014,
#  'processed': 116244,
#  'standard': 134547,
#  'procedures': 116216,
#  'following': 62210,
#  'primary': 115804,
#  'abcam': 20691,
#  'ab9106': 20642,
#  'r960': 120852,
#  'tubulin': 145078,
#  'santa': 128249,
#  'cruz': 45113,
#  'biotechnology': 32342,
#  'covalab': 44510,
#  'pab0847p': 108397,
#  'home': 74688,
#  'dilution': 51097,
#  'pab0882': 108398,
#  'raf1': 121200,
#  'sigma': 131621,
#  'f7425': 59740,
#  'actin': 21699,
#  'a5060': 19538,
#  'hrp': 75287,
#  'coupled': 44479,
#  'sc': 128538,
#  '2033': 6395,
#  'bio': 32074,
#  'rad': 120991,
#  '170': 4479,
#  '6516': 15365,
#  'rabbit': 120936,
#  '172': 4543,
#  '1019': 1528,
#  'secondary': 129391,
#  'chemiluminescence': 40474,
#  'supersignal': 136399,
#  'west': 151404,
#  'femto': 60646,
#  'thermo': 141253,
#  'purification': 118150,
#  'generated': 66524,
#  'bacmids': 30275,
#  'dh10bac': 50556,
#  'escherichia': 57779,
#  'coli': 42477,
#  'baculoviruses': 30303,
#  'sf9': 130638,
#  'bac': 30210,
#  'provider': 117145,
#  'infected': 79294,
#  'cdk10kd': 38985,
#  'producing': 116304,
#  'viruses': 149985,
#  'coinfected': 42405,
#  '72': 16237,
#  'infection': 79299,
#  'purify': 118156,
#  'ml': 96239,
#  'resuspended': 124176,
#  'pellet': 110630,
#  'lysate': 90695,
#  'soluble': 133191,
#  'fraction': 62672,
#  'time': 142021,
#  '100': 1392,
#  'glycerol': 68856,
#  'storage': 135131,
#  'transformed': 143418,
#  'origami2': 106252,
#  'de3': 48739,
#  'novagen': 103673,
#  'isopropyl': 81357,
#  'thiogalactopyranoside': 141445,
#  '300': 9231,
#  'imidazole': 78218,
#  'dtt': 53204,
#  'bar': 30570,
#  'disruptor': 51739,
#  '200': 6211,
#  'cobalt': 42172,
#  'incubation': 79027,
#  'elute': 56116,
#  'elution': 56122,
#  'eluted': 56117,
#  'mixed': 96139,
#  'harboring': 72161,
#  'monomeric': 97086,
#  'complexed': 43057,
#  'bsa': 34259,
#  'μci': 155353,
#  '32p': 9855,
#  '75': 16480,
#  'hcl': 72560,
#  'heparin': 73127,
#  'volume': 150273,
#  'reactions': 122099,
#  'laemli': 86902,
#  'cut': 46218,
#  'slices': 132492,
#  'stained': 134497,
#  'dried': 52958,
#  'incorporated': 78987,
#  'radioactivity': 121105,
#  'unrelated': 147343,
#  'girls': 67826,
#  'dysmorphic': 53591,
#  'facial': 59859,
#  'normal': 103484,
#  'intellect': 80085,
#  'toes': 142531,
#  'mother': 97456,
#  'daughter': 48502,
#  'pair1': 108553,
#  'table': 138177,
#  'supplementary': 136439,
#  'note': 103618,
#  'online': 105811,
#  'authors': 29557,
#  'noted': 103620,
#  'overlap': 106936,
#  'townes': 142938,
#  'brocks': 34073,
#  'represented': 123646,
#  'separate': 129855,
#  'autosomal': 29704,
#  'dominant': 52501,
#  'entity': 56898,
#  'mim601446': 95677,
#  'define': 49114,
#  'cardinal': 37083,
#  'characteristic': 40295,
#  'appearance': 26722,
#  'apparent': 26711,
#  'broad': 34052,
#  'tripartite': 144076,
#  'nasal': 100247,
#  'tip': 142091,
#  'variable': 149141,
#  'hypoplastic': 76443,
#  'labia': 86789,
#  'anal': 25130,
#  'atresia': 29216,
#  'urogenital': 147678,
#  '1a': 5611,
#  'figure': 61207,
#  'characterization': 40305,
#  'appearances': 26723,
#  'cases': 37301,
#  'dysplastic': 53616,
#  'ears': 54834,
#  'lips': 88984,
#  'illustrate': 78071,
#  'recognizable': 122453,
#  'parental': 109038,
#  'consent': 43558,
#  'publication': 117984,
#  'photographs': 112385,
#  'ray': 121845,
#  'films': 61413,
#  'feet': 60591,
#  'case': 37287,
#  'rays': 121851,
#  'delta': 49492,
#  'shaped': 130870,
#  '4th': 13081,
#  '5th': 14701,
#  'metatarsals': 94534,
#  'right': 124847,
#  'compare': 42909,
#  'picture': 112639,
#  ...}

# %%
vect_variation.vocabulary_
# Out:
# {'truncating': 2650,
#  'mutations': 1623,
#  'w802': 2878,
#  'q249e': 1913,
#  'n454d': 1667,
#  'l399v': 1440,
#  'v391i': 2743,
#  'v430m': 2747,
#  'deletion': 483,
#  'y371h': 2946,
#  'c384r': 224,
#  'p395a': 1813,
#  'k382e': 1243,
#  'r420q': 2179,
#  'c381a': 222,
#  'p428l': 1816,
#  'd390y': 372,
#  'q367p': 1922,
#  'm374v': 1593,
#  'y371s': 2947,
#  'h94y': 1097,
#  'c396r': 225,
#  'g375p': 918,
#  's376f': 2429,
#  'p417a': 1815,
#  'h398y': 1060,
#  's2g': 2409,
#  'y846c': 3005,
#  'c228t': 201,
#  'h412y': 1062,
#  'h876q': 1092,
#  'promoter': 1880,
#  'p704s': 1851,
#  'amplification': 155,
#  'c250t': 210,
#  'g1809r': 866,
#  'g1809k': 865,
#  'd1709e': 317,
#  'd1709a': 316,
#  'e1705a': 528,
#  'd1810a': 329,
#  'e1705k': 529,
#  't1365m': 2529,
#  'v648g': 2789,
#  't844m': 2628,
#  'a707t': 122,
#  'hypermethylation': 1100,
#  'r1343l': 2004,
#  'a209t': 72,
#  'y280h': 2933,
#  'd927g': 473,
#  'n510k': 1674,
#  'f248s': 742,
#  'l708p': 1499,
#  'v995m': 2828,
#  'y412f': 2954,
#  'f74s': 777,
#  'r1040l': 1964,
#  'r453c': 2183,
#  'r1209w': 1986,
#  'a1022e': 21,
#  'q984k': 1960,
#  't605m': 2602,
#  'k218t': 1221,
#  'n1125i': 1630,
#  'y35c': 2942,
#  'y35n': 2944,
#  'y35h': 2943,
#  'l234fs': 1406,
#  'l1273f': 1361,
#  'p284l': 1792,
#  'q276': 1915,
#  't286a': 2562,
#  't283a': 2561,
#  'i290a': 1146,
#  'i290r': 1147,
#  'a77s': 137,
#  'a77p': 136,
#  'a77t': 138,
#  'm90i': 1609,
#  'overexpression': 1735,
#  'n45s': 1668,
#  'r487q': 2196,
#  'c41y': 229,
#  'g52r': 948,
#  'p83l': 1859,
#  's241l': 2384,
#  's387y': 2436,
#  'tgfbr1': 2640,
#  '6a': 17,
#  'r537p': 2210,
#  'd404g': 376,
#  'p525l': 1832,
#  'r922': 2290,
#  'r976h': 2296,
#  'e1322': 507,
#  't1219i': 2520,
#  'g39e': 922,
#  'r1076c': 1966,
#  'r1095h': 1972,
#  'v509a': 2753,
#  'e946': 683,
#  'f1088lfs': 708,
#  'f1088sfs': 709,
#  'n1333gfs': 1637,
#  'k700r': 1313,
#  'r625c': 2224,
#  'e622d': 625,
#  'h662q': 1073,
#  'r625d': 2225,
#  'k666m': 1308,
#  'h662r': 1074,
#  'r625h': 2227,
#  'k666t': 1311,
#  'r625l': 2228,
#  'e622q': 626,
#  'r625g': 2226,
#  'k666n': 1309,
#  'k666r': 1310,
#  'k700e': 1312,
#  'r957q': 2293,
#  'l747_t751delinsp': 1508,
#  's752_i759del': 2485,
#  'i491m': 1160,
#  'd770_p772dup': 434,
#  'g719a': 967,
#  'g735s': 972,
#  'n771_h773dup': 1707,
#  'k467t': 1256,
#  'e746_t751insip': 654,
#  'd770_n771insd': 431,
#  'g724s': 971,
#  'k745_a750del': 1314,
#  'egfrviii': 688,
#  'v765a': 2807,
#  'egfrvii': 687,
#  'l858m': 1529,
#  'h870r': 1090,
#  'e758g': 658,
#  'h773l': 1083,
#  't710a': 2608,
#  'l747p': 1510,
#  'e709v': 641,
#  'd761y': 427,
#  'k806a': 1323,
#  'h773y': 1084,
#  'v851a': 2825,
#  'egfr': 686,
#  'rad51': 2300,
#  'fusion': 798,
#  'd770_n771insnpg': 432,
#  'e746_a750del': 648,
#  'a864t': 141,
#  'e746q': 656,
#  'exon': 704,
#  '19': 4,
#  'insertion': 1187,
#  'egfrvv': 690,
#  'a859_l883delinsv': 140,
#  'e709q': 640,
#  'e804g': 667,
#  'a750_e758del': 129,
#  'v769_d770insgvv': 2808,
#  'g796s': 982,
#  'r836c': 2272,
#  'p691s': 1850,
#  'g857e': 991,
#  'g719s': 970,
#  'l747v': 1512,
#  't783a': 2619,
#  'l692f': 1495,
#  'a750_e758delinsp': 130,
#  'v726m': 2803,
#  'e746v': 657,
#  'l747_p753delinss': 1506,
#  's768i': 2490,
#  'c620y': 251,
#  's921r': 2502,
#  'n826y': 1715,
#  'h773inslgnp': 1082,
#  'h773_v774insh': 1080,
#  'l747_a750delinsp': 1503,
#  'c628y': 252,
#  '20': 6,
#  'l704n': 1498,
#  'l861q': 1534,
#  'l747f': 1509,
#  'n826s': 1714,
#  'l747_e749del': 1504,
#  'l858q': 1530,
#  'l747_t751del': 1507,
#  'r108k': 1969,
#  'v774a': 2812,
#  's645c': 2471,
#  'l858r': 1531,
#  'kdd': 1332,
#  'l747_a750del': 1502,
#  'v774m': 2813,
#  'h773dup': 1081,
#  'e746g': 655,
#  'l861p': 1533,
#  'k745m': 1315,
#  'e746_t751delinsa': 652,
#  'l747s': 1511,
#  's492r': 2458,
#  's768_d770dup': 2488,
#  'd837n': 456,
#  'l861r': 1535,
#  'g719d': 969,
#  'e709_t710delinsd': 636,
#  'a763_y764insfqea': 133,
#  's784f': 2492,
#  'y801h': 2999,
#  'i744_k745delinskipvai': 1171,
#  'v742a': 2804,
#  'e746_a750delinsq': 649,
#  'l747_p753del': 1505,
#  't725m': 2609,
#  'l703p': 1497,
#  't790m': 2621,
#  'a767_v769dup': 135,
#  'e866k': 676,
#  'egfrviv': 689,
#  's768_v769insvas': 2489,
#  'e746_t751delinsva': 653,
#  'e734q': 647,
#  'r776h': 2261,
#  't263p': 2558,
#  't785a': 2620,
#  'a750p': 131,
#  'l838v': 1527,
#  'p753s': 1853,
#  'a767_v769del': 134,
#  'g863s': 994,
#  'i853t': 1178,
#  'l833v': 1525,
#  'r324l': 2153,
#  'v769m': 2810,
#  'w731l': 2875,
#  'e884k': 680,
#  't34_a289del': 2572,
#  'g719c': 968,
#  'e330k': 571,
#  's464l': 2453,
#  'r841k': 2274,
#  'd770_n771insvdsvdnp': 433,
#  'e746_s752delinsa': 650,
#  'r776c': 2260,
#  'e868g': 677,
#  'p848l': 1860,
#  'l861f': 1532,
#  'g810s': 983,
#  'purb': 1882,
#  'e709g': 638,
#  'e709k': 639,
#  'p596l': 1844,
#  'e709a': 637,
#  'd587h': 397,
#  'g863d': 993,
#  'l838p': 1526,
#  'e746_s752delinsi': 651,
#  'v843i': 2823,
#  'g465e': 934,
#  'igh': 1184,
#  'nkx2': 1725,
#  'trb': 2647,
#  'fusions': 799,
#  'tra': 2645,
#  'a339v': 86,
#  'a113_splice': 27,
#  'brd4': 170,
#  'nut': 1734,
#  's102f': 2313,
#  'k373e': 1239,
#  'i157t': 1121,
#  'e161del': 522,
#  'p85l': 1861,
#  's428f': 2439,
#  'r117g': 1978,
#  'e321k': 567,
#  'tmprss2': 2641,
#  'etv1': 698,
#  'etv5': 700,
#  'etv4': 699,
#  't75m': 2614,
#  'm160v': 1561,
#  'g35r': 913,
#  'k28m': 1228,
#  'g35v': 914,
#  'i279p': 1143,
#  'r331p': 2154,
#  's330a': 2416,
#  's308a': 2410,
#  'k320e': 1235,
#  's1986f': 2363,
#  'd2033n': 334,
#  's1986y': 2364,
#  'ezr': 705,
#  'ros1': 2307,
#  'l1947r': 1394,
#  'cd74': 274,
#  'lima1': 1543,
#  'v2098i': 2709,
#  'g2032r': 870,
#  'g1971e': 868,
#  'kdelr2': 1333,
#  'slc34a2': 2506,
#  'l1951r': 1395,
#  'msn': 1622,
#  'lrig3': 1546,
#  'sdc4': 2503,
#  'tfg': 2639,
#  'g2101a': 873,
#  'cep85l': 276,
#  'c2060g': 200,
#  'ccdc6': 271,
#  'e1935g': 537,
#  'fig': 794,
#  'r732q': 2257,
#  'a617t': 113,
#  'd254n': 341,
#  'a634v': 118,
#  'a298t': 85,
#  't340a': 2570,
#  'd257n': 342,
#  'epigenetic': 692,
#  'silencing': 2505,
#  'y1414c': 2908,
#  'r1627': 2033,
#  'c1385': 188,
#  'ep300': 691,
#  'moz': 1620,
#  'd1399y': 308,
#  'mll': 1619,
#  'p1502l': 1748,
#  '534_536del': 13,
#  'p531l': 1834,
#  'a530v': 103,
#  'p531s': 1835,
#  'a530t': 102,
#  'y532c': 2963,
#  'p531a': 1833,
#  '533_534del': 12,
#  's215g': 2370,
#  'r273l': 2127,
#  'r202s': 2078,
#  'h179q': 1034,
#  'k120e': 1199,
#  'c277q': 212,
#  'r290h': 2141,
#  'r337p': 2158,
#  'p278s': 1791,
#  'y234h': 2923,
#  'c277w': 214,
#  's241t': 2385,
#  'v173e': 2690,
#  'q331r': 1919,
#  'h115n': 1013,
#  'p219s': 1776,
#  'r249w': 2102,
#  'v274f': 2719,
#  'r175c': 2057,
#  'r248w': 2099,
#  's121a': 2326,
#  'y220s': 2921,
#  'p153h': 1753,
#  'r181c': 2063,
#  'r337c': 2155,
#  'k120n': 1201,
#  'g245d': 882,
#  'r175h': 2058,
#  'r181l': 2065,
#  'g244s': 880,
#  's240r': 2382,
#  'r273c': 2124,
#  'e221q': 544,
#  'q331h': 1918,
#  'y220c': 2920,
#  'r342p': 2160,
#  'c242f': 205,
#  'c242s': 206,
#  'c135s': 183,
#  'm237k': 1585,
#  'v197l': 2706,
#  's121c': 2327,
#  's241f': 2383,
#  'dna': 486,
#  'binding': 168,
#  'domain': 488,
#  'deletions': 484,
#  'r248k': 2096,
#  'h214r': 1049,
#  'l330r': 1426,
#  'p151s': 1751,
#  'r110l': 1974,
#  'c176f': 197,
#  'h179y': 1036,
#  'c277r': 213,
#  'l344r': 1428,
#  'r267q': 2121,
#  'r156h': 2018,
#  'd186a': 332,
#  'c275s': 211,
#  'e285k': 558,
#  'insertions': 1188,
#  'v157d': 2675,
#  'y236s': 2926,
#  'r337h': 2156,
#  'r213q': 2082,
#  'r280k': 2131,
#  'r110p': 1975,
#  'r249s': 2101,
#  'h168n': 1027,
#  'r290g': 2140,
#  'h193p': 1043,
#  'n239s': 1653,
#  'l348s': 1431,
#  'm133t': 1556,
#  'h179l': 1032,
#  'g244r': 879,
#  'p316l': 1803,
#  'h297n': 1055,
#  'v272l': 2718,
#  'g244d': 878,
#  'g245s': 883,
#  'l348f': 1430,
#  'y163c': 2912,
#  'h179n': 1033,
#  'n235d': 1651,
#  'h168r': 1028,
#  'e285v': 559,
#  'i255f': 1139,
#  'r158h': 2022,
#  'a161t': 52,
#  'p278a': 1788,
#  'r249m': 2100,
#  'f341c': 748,
#  'k292t': 1232,
#  'g266r': 890,
#  'h179r': 1035,
#  'c141y': 189,
#  'v143a': 2667,
#  'e326l': 569,
#  'c229r': 202,
#  'k291q': 1230,
#  'q144r': 1889,
#  'r248q': 2098,
#  'p250l': 1782,
#  'a347t': 87,
#  'v157f': 2676,
#  'i251s': 1138,
#  'f134y': 721,
#  'p152l': 1752,
#  'g199r': 869,
#  'i162m': 1125,
#  'c135r': 182,
#  'missense': 1617,
#  'a161s': 51,
#  'g334r': 908,
#  'v173l': 2691,
#  'r158l': 2023,
#  'h193n': 1042,
#  'r175l': 2059,
#  'p47s': 1825,
#  'r280a': 2130,
#  'r280t': 2132,
#  'k292i': 1231,
#  'y236c': 2924,
#  'r248l': 2097,
#  'r156c': 2017,
#  'y236d': 2925,
#  't150i': 2531,
#  'l344p': 1427,
#  'h233n': 1051,
#  'p278l': 1789,
#  'k291e': 1229,
#  'e258v': 550,
#  's241y': 2386,
#  'c238f': 203,
#  'f212y': 739,
#  'r282w': 2134,
#  'r267p': 2120,
#  'h214q': 1048,
#  't123a': 2521,
#  's215c': 2369,
#  'r282q': 2133,
#  'r273h': 2126,
#  'g245a': 881,
#  'c135y': 184,
#  'r283q': 2135,
#  'r181h': 2064,
#  'p151h': 1750,
#  'f328v': 747,
#  'y234c': 2922,
#  'p151a': 1749,
#  'r273g': 2125,
#  'v197e': 2705,
#  'e286k': 560,
#  'k120m': 1200,
#  'i195t': 1131,
#  'g356a': 911,
#  'r158c': 2021,
#  'h214n': 1047,
#  'c238s': 204,
#  'l145r': 1367,
#  'p278r': 1790,
#  'r337l': 2157,
#  'g266e': 889,
#  'r321q': 2152,
#  'p305l': 1801,
#  'f346v': 750,
#  'v319d': 2728,
#  'w368h': 2857,
#  'd450e': 383,
#  'y406h': 2952,
#  'k420a': 1249,
#  't413n': 2578,
#  's276l': 2406,
#  'd300h': 354,
#  'k375a': 1240,
#  'n387p': 1666,
#  'y426a': 2956,
#  'r428a': 2181,
#  'd300n': 355,
#  'r310h': 2149,
#  'd450h': 384,
#  'y298a': 2936,
#  'k341a': 1237,
#  'v356r': 2737,
#  'd258n': 343,
#  'r373h': 2169,
#  'r287a': 2138,
#  'y297a': 2935,
#  'y238a': 2928,
#  'r243a': 2092,
#  'r373q': 2170,
#  'r292a': 2142,
#  'e239a': 545,
#  'd408y': 379,
#  'y384a': 2951,
#  'w406a': 2860,
#  'd408h': 378,
#  'r268a': 2122,
#  'd408e': 377,
#  'v277d': 2720,
#  's425c': 2437,
#  'y237a': 2927,
#  'p336s': 1805,
#  'd537e': 390,
#  'w509r': 2861,
#  'k507q': 1262,
#  'd537y': 391,
#  'g508s': 947,
#  'r378a': 2171,
#  'r441p': 2182,
#  'r361c': 2164,
#  'l43v': 1445,
#  'r497h': 2201,
#  'r515g': 2209,
#  'w398v': 2859,
#  'g419v': 923,
#  'r420h': 2178,
#  'y513a': 2962,
#  'v465m': 2749,
#  'd493a': 387,
#  'v370d': 2740,
#  'r100t': 1963,
#  'p130s': 1744,
#  'k507a': 1261,
#  'e330g': 570,
#  'k428a': 1250,
#  'r496h': 2200,
#  'c324y': 218,
#  'y353l': 2941,
#  'd351h': 368,
#  'a532h': 104,
#  'd357y': 369,
#  'h132y': 1019,
#  'r24c': 2103,
#  'k22a': 1222,
#  'a197t': 68,
#  'r465h': 2187,
#  's562l': 2464,
#  'r479l': 2190,
#  's462y': 2451,
#  's227a': 2379,
#  'd520n': 389,
#  'r479q': 2191,
#  'r479h': 2189,
#  'r658q': 2234,
#  'r505c': 2205,
#  'r689q': 2248,
#  'k11r': 1198,
#  't205a': 2551,
#  'r505l': 2206,
#  'i347m': 1152,
#  'copy': 279,
#  'number': 1732,
#  'loss': 1545,
#  'g423r': 924,
#  'r482q': 2194,
#  's31r': 2413,
#  'p133t': 1746,
#  'v109g': 2657,
#  'q50p': 1928,
#  'p114l': 1738,
#  'e69g': 634,
#  'g67r': 961,
#  'l97r': 1540,
#  'd84g': 466,
#  'q50': 1927,
#  'v126d': 2662,
#  'd84h': 467,
#  'm53i': 1598,
#  't77p': 2618,
#  'n71i': 1704,
#  'g67s': 962,
#  'n71s': 1706,
#  'r80p': 2267,
#  'd84v': 469,
#  'd74n': 425,
#  'd74y': 426,
#  'p81l': 1856,
#  'l32p': 1425,
#  'd108h': 295,
#  'd84y': 470,
#  'n71k': 1705,
#  'r24p': 2104,
#  'r99p': 2299,
#  'a148t': 46,
#  'g23d': 876,
#  'r80l': 2266,
#  'g35a': 912,
#  'h83y': 1087,
#  'a36p': 90,
#  'p48l': 1827,
#  'd108n': 296,
#  'p81t': 1857,
#  'g101w': 801,
#  'a57v': 106,
#  'r87l': 2280,
#  'h83n': 1086,
#  'd84n': 468,
#  'p114s': 1739,
#  'i49s': 1161,
#  'r112g': 1976,
#  's56i': 2467,
#  'r79p': 2263,
#  'a60v': 111,
#  'r87p': 2281,
#  'e88k': 681,
#  'g93w': 1000,
#  'v118d': 2660,
#  'e35': 572,
#  'p40t': 1814,
#  'd86n': 471,
#  'a23e': 76,
#  'e812k': 668,
#  'l49h': 1460,
#  'r678q': 2242,
#  't798m': 2623,
#  'd808n': 436,
#  'v659e': 2794,
#  's760a': 2486,
#  'v839g': 2821,
#  'l866m': 1536,
#  'c630y': 254,
#  'i767m': 1172,
#  's1002r': 2310,
#  'e719g': 644,
#  'k753e': 1317,
#  'e719k': 645,
#  'y772_a775dup': 2997,
#  'g776s': 979,
#  's310f': 2411,
#  's335c': 2417,
#  'l785f': 1518,
#  'l915m': 1538,
#  'c334s': 219,
#  'g776delinsvc': 978,
#  'g660d': 959,
#  'v777a': 2814,
#  'k753m': 1318,
#  'v842i': 2822,
#  'v750e': 2805,
#  'n319d': 1658,
#  'v773a': 2811,
#  'e717k': 643,
#  'k753a': 1316,
#  't733i': 2611,
#  'y835f': 3003,
#  's653c': 2473,
#  'm774_a775insayvm': 1606,
#  'd769h': 429,
#  'l726i': 1501,
#  'h878y': 1093,
#  'l755s': 1515,
#  'd821n': 449,
#  'g309a': 896,
#  'e265k': 551,
#  'd769y': 430,
#  't798i': 2622,
#  'l755p': 1514,
#  'y1248f': 2902,
#  'p780l': 1854,
#  'v777l': 2815,
#  's783p': 2491,
#  'd769a': 428,
#  'c311r': 217,
#  'g776delinslc': 977,
#  'd277h': 347,
#  'r143q': 2010,
#  'g309e': 897,
#  'e321g': 566,
#  'l726f': 1500,
#  'v777m': 2816,
#  'y803n': 3000,
#  'n857s': 1719,
#  'd845a': 464,
#  'g778_p780dup': 980,
#  's310y': 2412,
#  'v794m': 2817,
#  'g776_v777insyvma': 976,
#  's846i': 2496,
#  'a1131t': 26,
#  'g284r': 893,
#  'p262h': 1786,
#  'v714m': 2801,
#  't389k': 2576,
#  'q809r': 1957,
#  'r669c': 2239,
#  'a232v': 74,
#  'v104m': 2652,
#  'e452k': 585,
#  'erbb4': 693,
#  'r306s': 2148,
#  'e563k': 613,
#  'v348l': 2735,
#  't244r': 2556,
#  'y285c': 2934,
#  'r544w': 2212,
#  'm887i': 1608,
#  'd595v': 404,
#  'n181s': 1643,
#  'r838q': 2273,
#  'g785s': 981,
#  'g936r': 999,
#  'e317k': 564,
#  'e542k': 602,
#  'e872k': 678,
#  'k935i': 1328,
#  'e836k': 673,
#  'g665a': 960,
#  'e606g': 622,
#  'a717g': 123,
#  'n238s': 1652,
#  's746fs': 2484,
#  'r631c': 2229,
#  'd609e': 408,
#  'd513y': 388,
#  'v536m': 2756,
#  'r487w': 2197,
#  'p463l': 1823,
#  'l461v': 1448,
#  'r592h': 2219,
#  'y24c': 2929,
#  'd423n': 382,
#  'f568fs': 767,
#  'v242f': 2713,
#  'r601q': 2221,
#  'a349p': 88,
#  'p47a': 1824,
#  'm299i': 1590,
#  'r173c': 2048,
#  'k52r': 1271,
#  'r109': 1970,
#  'r689s': 2249,
#  'e875g': 679,
#  'l230p': 1404,
#  's786f': 2493,
#  'bcr': 165,
#  'abl1': 148,
#  'l248v': 1413,
#  'g250e': 885,
#  'm244v': 1586,
#  'e355a': 573,
#  'l387m': 1437,
#  'e281k': 556,
#  'e459k': 587,
#  'f311l': 744,
#  'y253f': 2930,
#  't315i': 2565,
#  'e279k': 555,
#  'e255v': 549,
#  'e255k': 548,
#  'h396p': 1058,
#  'y253h': 2931,
#  'v299l': 2726,
#  'l384m': 1436,
#  'v379i': 2741,
#  'm351t': 1591,
#  'v289f': 2721,
#  'q252h': 1914,
#  'f317l': 745,
#  'h396r': 1059,
#  'f359c': 754,
#  'erg': 694,
#  'ewsr1': 703,
#  'fus': 797,
#  '596_619splice': 16,
#  'c450_k451insmiewmi': 234,
#  'a633t': 115,
#  'r481g': 2193,
#  'h845y': 1089,
#  'kdr': 1334,
#  'pdgfra': 1873,
#  'n870s': 1720,
#  'q579r': 1941,
#  'r748g': 2258,
#  'c456_n468del': 235,
#  'n659k': 1698,
#  'h570r': 1066,
#  'y555c': 2971,
#  's584l': 2468,
#  'e996k': 684,
#  'v536e': 2755,
#  's478p': 2457,
#  'i843_d846del': 1175,
#  'h650q': 1071,
#  'g829r': 987,
#  'a633v': 116,
#  'v561_i562inser': 2772,
#  'i562m': 1164,
#  'y375_k455del': 2949,
#  'v561a': 2773,
#  'd842_m844del': 460,
#  'k830r': 1325,
#  'd842_h845del': 459,
#  's566_e571delinsr': 2465,
#  'd842i': 461,
#  'n659r': 1699,
#  'kif5b': 1338,
#  'y849s': 3007,
#  'i834v': 1173,
#  'd1071n': 293,
#  'g853d': 989,
#  'd842v': 462,
#  't674i': 2607,
#  'p577s': 1843,
#  'e311_k312del': 563,
#  'w349c': 2856,
#  'd846y': 465,
#  'n848k': 1718,
#  'i843del': 1176,
#  'l507p': 1461,
#  'n659s': 1700,
#  'v561d': 2774,
#  'c456_r481del': 236,
#  'h845_n848delinsp': 1088,
#  'strn': 2513,
#  'd842y': 463,
#  'y849c': 3006,
#  '560_561inser': 15,
#  'etv6': 701,
#  'v658a': 2792,
#  'v544_l545insavlvllviviisli': 2757,
#  'f808l': 779,
#  'kank1': 1331,
#  'pdgfrb': 1874,
#  'r987w': 2298,
#  'nin': 1724,
#  'gpiap1': 1003,
#  'golga4': 1002,
#  'wdr48': 2880,
#  'tp53bp1': 2642,
#  'prkg2': 1879,
#  'ebf1': 685,
#  'atf7ip': 159,
#  'e1071w': 496,
#  'pde4dip': 1872,
#  'bin2': 167,
#  'r561c': 2215,
#  'git2': 1001,
#  'sptbn1': 2510,
#  'hip1': 1098,
#  'kiaa1509': 1335,
#  'v665a': 2795,
#  'v354e': 2736,
#  'd402y': 375,
#  'p480l': 1826,
#  'v1075yfs': 2655,
#  'm1_e165del': 1577,
#  'v534e': 2754,
#  'l536p': 1466,
#  'l469v': 1449,
#  's463p': 2452,
#  'e380q': 576,
#  'a546d': 105,
#  'esr1': 696,
#  'yap1': 3014,
#  'l536q': 1467,
#  'l536h': 1465,
#  'v422del': 2746,
#  'ccdc170': 270,
#  'l536r': 1468,
#  's432l': 2440,
#  'y537c': 2964,
#  'y537s': 2965,
#  'r418g': 2177,
#  'r369q': 2166,
#  'p214l': 1775,
#  'r369w': 2167,
#  '385_418del': 9,
#  'flt3': 796,
#  'ntrk3': 1731,
#  'm224r': 1582,
#  'f158c': 725,
#  'k82t': 1324,
#  's35q': 2424,
#  'l117p': 1348,
#  'h68r': 1075,
#  'r246k': 2094,
#  't417i': 2581,
#  'g305w': 895,
#  'n198_f199delinsi': 1645,
#  'v220f': 2712,
#  'h105r': 1007,
#  'g305r': 894,
#  'v128del': 2663,
#  'h206d': 1045,
#  'g1035s': 802,
#  'l191h': 1392,
#  'l180p': 1385,
#  'r1097h': 1973,
#  's1036p': 2314,
#  'g1567d': 844,
#  'l410r': 1441,
#  'v299g': 2725,
#  'h1620r': 1024,
#  'l1584r': 1372,
#  'q1554h': 1893,
#  't1623i': 2533,
#  'h597y': 1067,
#  'e1552del': 518,
#  't1203k': 2519,
#  'v1673f': 2683,
#  'v705m': 2799,
#  'p1675l': 1756,
#  'g1596v': 845,
#  'r905w': 2289,
#  'r905q': 2288,
#  'v1673d': 2682,
#  'r611w': 2223,
#  'l830r': 1524,
#  's1653p': 2348,
#  'r905g': 2287,
#  's1653f': 2347,
#  'v769e': 2809,
#  'q1503p': 1892,
#  'a889p': 144,
#  'w1610g': 2837,
#  'r462c': 2184,
#  'r1200w': 1983,
#  'l792r': 1521,
#  'l493v': 1459,
#  'l493p': 1458,
#  'c696y': 260,
#  'l826p': 1522,
#  'a614d': 112,
#  'l146r': 1369,
#  'r611q': 2222,
#  's1498n': 2339,
#  'f615s': 774,
#  'y598c': 2976,
#  'v705e': 2798,
#  'l844r': 1528,
#  'l448p': 1446,
#  'p1709l': 1759,
#  'e75g': 659,
#  'fev': 789,
#  'yy1': 3015,
#  'ddit3': 482,
#  'fli1': 795,
#  'nr4a3': 1728,
#  'creb1': 281,
#  'atf1': 158,
#  'wt1': 2882,
#  'r206h': 2080,
#  'g328e': 905,
#  'g328v': 906,
#  'g87r': 995,
#  'l388m': 1438,
#  's453fs': 2443,
#  'l455m': 1447,
#  'f400i': 759,
#  'm253k': 1587,
#  'y646n': 2988,
#  'y646f': 2986,
#  'y646h': 2987,
#  'y646c': 2985,
#  ...}

# %%
gene_variation.vocabulary_
# Out:
# {'fam58a': 85,
#  'cbl': 39,
#  'shoc2': 227,
#  'tert': 245,
#  'dicer1': 62,
#  'ptprt': 198,
#  'rheb': 213,
#  'shq1': 228,
#  'ccnd2': 41,
#  'rad50': 202,
#  'ccnd3': 42,
#  'rit1': 216,
#  'ccne1': 43,
#  'rybp': 222,
#  'tgfbr1': 248,
#  'tgfbr2': 249,
#  'msh6': 154,
#  'kmt2d': 134,
#  'lats1': 137,
#  'pbrm1': 177,
#  'sf3b1': 226,
#  'lats2': 138,
#  'egfr': 66,
#  'nkx2': 165,
#  'eif1ax': 67,
#  'arid2': 12,
#  'brd4': 33,
#  'hist1h1c': 110,
#  'errfi1': 79,
#  'chek2': 55,
#  'pak1': 175,
#  'tmprss2': 250,
#  'h3f3a': 109,
#  'elf3': 68,
#  'ros1': 218,
#  'asxl2': 15,
#  'cdh1': 44,
#  'epcam': 71,
#  'ep300': 69,
#  'epas1': 70,
#  'tp53': 251,
#  'tp53bp1': 252,
#  'smad2': 229,
#  'smad3': 230,
#  'smad4': 231,
#  'cdk4': 46,
#  'aurkb': 20,
#  'cdk6': 47,
#  'fbxw7': 89,
#  'cdk8': 48,
#  'cdkn1a': 49,
#  'cdkn1b': 50,
#  'cdkn2a': 51,
#  'cdkn2b': 52,
#  'cdkn2c': 53,
#  'asxl1': 14,
#  'erbb2': 72,
#  'erbb3': 73,
#  'erbb4': 74,
#  'ercc2': 75,
#  'brip1': 34,
#  'ercc3': 76,
#  'ercc4': 77,
#  'abl1': 0,
#  'cebpa': 54,
#  'erg': 78,
#  'hla': 111,
#  'pdgfra': 178,
#  'pdgfrb': 179,
#  'rbm10': 211,
#  'kdm5c': 125,
#  'esr1': 80,
#  'etv1': 81,
#  'etv6': 82,
#  'tsc1': 253,
#  'ikzf1': 118,
#  'tsc2': 254,
#  'ewsr1': 83,
#  'acvr1': 1,
#  'foxa1': 99,
#  'mdm2': 144,
#  'arid1a': 10,
#  'ezh2': 84,
#  'mdm4': 145,
#  'klf4': 130,
#  'rxra': 221,
#  'map3k1': 142,
#  'axin1': 21,
#  'bap1': 24,
#  'men1': 148,
#  'fanca': 86,
#  'fancc': 87,
#  'met': 149,
#  'u2af1': 255,
#  'kmt2c': 133,
#  'fat1': 88,
#  'arid1b': 11,
#  'pik3ca': 180,
#  'pik3cb': 181,
#  'pim1': 186,
#  'pik3cd': 182,
#  'yap1': 262,
#  'pik3r1': 183,
#  'pik3r2': 184,
#  'arid5b': 13,
#  'hras': 113,
#  'mlh1': 151,
#  'fgf3': 91,
#  'fgf4': 92,
#  'kmt2a': 131,
#  'akt1': 3,
#  'akt2': 4,
#  'fgfr1': 93,
#  'fgfr3': 95,
#  'spop': 237,
#  'fgfr2': 94,
#  'fgfr4': 96,
#  'kdm6a': 126,
#  'alk': 6,
#  'sdhb': 223,
#  'rad54l': 206,
#  'sdhc': 224,
#  'vegfa': 256,
#  'mpl': 152,
#  'pms1': 187,
#  'carm1': 37,
#  'foxo1': 101,
#  'vhl': 257,
#  'map2k4': 141,
#  'rras2': 219,
#  'flt1': 97,
#  'flt3': 98,
#  'pms2': 188,
#  'srsf2': 239,
#  'whsc1': 258,
#  'ppm1d': 190,
#  'pole': 189,
#  'knstrn': 135,
#  'pik3r3': 185,
#  'apc': 7,
#  'rictor': 215,
#  'msh2': 153,
#  'idh1': 114,
#  'idh2': 115,
#  'xpo1': 260,
#  'xrcc2': 261,
#  'crebbp': 57,
#  'ar': 8,
#  'araf': 9,
#  'rhoa': 214,
#  'ncor1': 160,
#  'ppp2r1a': 191,
#  'setd2': 225,
#  'igf1r': 116,
#  'ppp6c': 192,
#  'ctcf': 58,
#  'ikbke': 117,
#  'mtor': 155,
#  'tet1': 246,
#  'smarca4': 232,
#  'smarcb1': 233,
#  'foxp1': 102,
#  'smo': 234,
#  'card11': 36,
#  'mef2b': 147,
#  'ctla4': 59,
#  'atm': 16,
#  'nup93': 174,
#  'mapk1': 143,
#  'ctnnb1': 60,
#  'map2k1': 139,
#  'map2k2': 140,
#  'stag2': 240,
#  'il7r': 119,
#  'sos1': 235,
#  'myc': 156,
#  'mycn': 157,
#  'sox9': 236,
#  'tet2': 247,
#  'myd88': 158,
#  'ago2': 2,
#  'kmt2b': 132,
#  'atr': 17,
#  'atrx': 18,
#  'cdk12': 45,
#  'axl': 22,
#  'myod1': 159,
#  'b2m': 23,
#  'src': 238,
#  'gata3': 104,
#  'bard1': 25,
#  'ccnd1': 40,
#  'bcl2': 27,
#  'keap1': 128,
#  'ptch1': 194,
#  'pten': 195,
#  'bcor': 29,
#  'rnf43': 217,
#  'cic': 56,
#  'inpp4b': 120,
#  'stat3': 241,
#  'whsc1l1': 259,
#  'prdm1': 193,
#  'jak1': 121,
#  'jak2': 122,
#  'aurka': 19,
#  'stk11': 242,
#  'jun': 123,
#  'ptpn11': 196,
#  'nf1': 161,
#  'foxl2': 100,
#  'ptprd': 197,
#  'brca1': 31,
#  'braf': 30,
#  'brca2': 32,
#  'nf2': 162,
#  'pax8': 176,
#  'nfe2l2': 163,
#  'gli1': 105,
#  'fubp1': 103,
#  'btk': 35,
#  'nfkbia': 164,
#  'gna11': 106,
#  'kdr': 127,
#  'bcl10': 26,
#  'gnaq': 107,
#  'gnas': 108,
#  'mga': 150,
#  'kit': 129,
#  'fgf19': 90,
#  'med12': 146,
#  'notch1': 166,
#  'notch2': 167,
#  'rac1': 200,
#  'dnmt3a': 63,
#  'dnmt3b': 64,
#  'rad21': 201,
#  'rad51c': 204,
#  'rad51b': 203,
#  'rad51d': 205,
#  'kras': 136,
#  'npm1': 168,
#  'raf1': 207,
#  'rab35': 199,
#  'hnf1a': 112,
#  'akt3': 5,
#  'tcf3': 243,
#  'tcf7l2': 244,
#  'rara': 208,
#  'nras': 169,
#  'rasa1': 209,
#  'bcl2l11': 28,
#  'rb1': 210,
#  'kdm5a': 124,
#  'ntrk1': 171,
#  'ntrk2': 172,
#  'ntrk3': 173,
#  'dusp4': 65,
#  'ddr2': 61,
#  'nsd1': 170,
#  'casp8': 38,
#  'ret': 212,
#  'runx1': 220}

# %%
#transforming count of Variation words in to matrix
variation_tranform_train_A=vect_variation.transform(X_A["Variation"])
variation_tranform_train_B=vect_variation.transform(X_B["Variation"])
variation_tranform_train_m=vect_variation.transform(X_m["Variation"])

# %%
#transforming count of Text words in to matrix
text_transformed_train_A= vect_text.transform(X_A["Text"])
text_transformed_train_B= vect_text.transform(X_B["Text"])
text_transformed_train_m= vect_text.transform(X_m["Text"])

# %%
#transforming count of gene words in to matrix
gene_transformed_train_A= gene_variation.transform(X_A["Gene"])
gene_transformed_train_B= gene_variation.transform(X_B["Gene"])
gene_transformed_train_m= gene_variation.transform(X_m["Gene"])

# %%
#merging train data of two Matrix horixzontally to train the model
import scipy.sparse as sp
XA_final = sp.hstack((variation_tranform_train_A,text_transformed_train_A,gene_transformed_train_A))
XB_final = sp.hstack((variation_tranform_train_B,text_transformed_train_B,gene_transformed_train_B))
Xm_final = sp.hstack((variation_tranform_train_m,text_transformed_train_m,gene_transformed_train_m))

# %%
XA_final.shape
# Out:
# (662, 158717)

# %%
XB_final.shape
# Out:
# (2659, 158717)

# %%
yA.shape
# Out:
# (662,)

# %%
yB.shape
# Out:
# (2659,)

# %%
Xm_final.shape
# Out:
# (3321, 158717)

# %%
ym.shape
# Out:
# (3321,)

# %%
# splitting into test and train
from sklearn.model_selection  import train_test_split
from imblearn.over_sampling import SMOTE
XA_train, XA_test, yA_train, yA_test = train_test_split(XA_final, yA, random_state=1)

# %%
XB_train, XB_test, yB_train, yB_test = train_test_split(XB_final, yB, random_state=1)

# %%
print(XA_train.shape)
# Out:
# (496, 158717)

# %%
print(yA_train.shape)
# Out:
# (496,)

# %%
print(XA_test.shape)
# Out:
# (166, 158717)

# %%
print(yA_test.shape)
# Out:
# (166,)

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report 
# Model Generation Using Multinomial Naive Bayes
clfA = MultinomialNB().fit(XA_train, yA_train)
predicted= clfA.predict(XA_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(yA_test, predicted))
print(classification_report(yA_test,predicted))
# Out:
# MultinomialNB Accuracy: 0.7590361445783133
#               precision    recall  f1-score   support
#
#            3       0.86      0.60      0.71        20
#            5       0.68      0.78      0.72        54
#            6       0.83      0.82      0.83        78
#            8       0.50      0.20      0.29         5
#            9       0.64      0.78      0.70         9
#
#     accuracy                           0.76       166
#    macro avg       0.70      0.64      0.65       166
# weighted avg       0.76      0.76      0.76       166

# %%
# Model Generation Using Multinomial Naive Bayes
clfB = MultinomialNB().fit(XB_train, yB_train)
predicted= clfB.predict(XB_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(yB_test, predicted))
print(classification_report(yB_test,predicted))
# Out:
# MultinomialNB Accuracy: 0.6827067669172933
#               precision    recall  f1-score   support
#
#            1       0.61      0.71      0.66       140
#            2       0.50      0.52      0.51       117
#            4       0.79      0.65      0.71       175
#            7       0.76      0.77      0.76       233
#
#     accuracy                           0.68       665
#    macro avg       0.67      0.66      0.66       665
# weighted avg       0.69      0.68      0.68       665

# %%
from sklearn.ensemble import VotingClassifier

# %%
#Using Average weighting on the models that we have generated
#Using a voting classifier on Multinomial NB after hyperparameter tuning would be a waste as it NB is a pretty simple Model

# %%
Xm_train, Xm_test, ym_train, ym_test = train_test_split(Xm_final, ym, random_state=1)

# %%
# Model Generation Using Multinomial Naive Bayes
clfm = MultinomialNB().fit(Xm_train, ym_train)
predict= clfm.predict(Xm_test)
print("MultinomialNB Accuracy:",metrics.accuracy_score(ym_test, predict))
print(classification_report(ym_test,predict))
# Out:
# MultinomialNB Accuracy: 0.5812274368231047
#               precision    recall  f1-score   support
#
#            1       0.50      0.61      0.55       142
#            2       0.41      0.46      0.44       117
#            3       0.50      0.26      0.34        27
#            4       0.77      0.54      0.63       170
#            5       0.33      0.48      0.39        50
#            6       0.73      0.57      0.64        61
#            7       0.67      0.70      0.69       250
#            8       1.00      0.20      0.33         5
#            9       0.73      0.89      0.80         9
#
#     accuracy                           0.58       831
#    macro avg       0.63      0.52      0.54       831
# weighted avg       0.61      0.58      0.58       831

# %%
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn import datasets
from sklearn.multiclass import OneVsRestClassifier

# %%
#We see that the accuracy is skewed for the entire model as the data is imbalanced as we saw in the class distribution

# %%
#We would now try to tune the SVM hyperparameters and stack the classifiers built from them to be able to aid out 
#our final machine learning model

# %%
#Tuning the hyperparameters for the minority data

# %%
from sklearn.model_selection import GridSearchCV 
  
# defining parameter range 
param_grid = {'C': [0.1, 1], #10, 100, 1000],  
              'gamma': [1, 0.1, 0.01], #0.001, 0.0001], 
              'kernel': ['linear']}  
  
gridA = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3,) 
  
# fitting the model for grid search 
gridA.fit(XA_train, yA_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.665, total=  13.3s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.3s remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.651, total=  11.4s
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   24.6s remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.718, total=  12.8s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.665, total=  12.7s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.651, total=  11.2s
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.718, total=  13.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.665, total=  12.5s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.651, total=  11.1s
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.718, total=  12.6s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.677, total=  13.4s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.657, total=  11.8s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.712, total=  14.9s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.677, total=  13.6s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.657, total=  11.7s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.712, total=  15.0s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.677, total=  14.2s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.657, total=  11.4s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.712, total=  14.6s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:  3.9min finished
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=True, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.1, 1], 'gamma': [1, 0.1, 0.01],
#                          'kernel': ['linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning 
print(gridA.best_params_) 
  
# print how our model looks after hyper-parameter tuning 
print(gridA.best_estimator_)
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'linear'}
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='linear',
#     max_iter=-1, probability=True, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
gridA_predictions = gridA.predict(XA_test) 
  
# print classification report 
print(classification_report(yA_test, gridA_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.65      0.75      0.70        20
#            5       0.78      0.72      0.75        54
#            6       0.84      0.87      0.86        78
#            8       0.60      0.60      0.60         5
#            9       1.00      0.78      0.88         9
#
#     accuracy                           0.80       166
#    macro avg       0.77      0.74      0.76       166
# weighted avg       0.80      0.80      0.80       166

# %%
# defining parameter range 
param_grid = {'C': [0.1, 1], #10, 100, 1000],  
              'gamma': [1],
              'kernel': ['linear']}  
gridB = GridSearchCV(SVC(probability=True), param_grid, refit = True, verbose = 3) 
  
# fitting the model for grid search 
gridB.fit(XB_train, yB_train)
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.647, total= 2.1min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.1min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.674, total= 2.2min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  4.3min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.673, total= 2.4min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.647, total= 2.4min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.684, total= 2.6min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.694, total= 2.6min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 14.4min finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#              estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto_deprecated', kernel='rbf', max_iter=-1,
#                            probability=True, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'C': [0.1, 1], 'gamma': [1], 'kernel': ['linear']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
gridB_predictions = gridB.predict(XB_test) 
  
# print classification report 
print(classification_report(yB_test, gridB_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.63      0.65      0.64       140
#            2       0.54      0.56      0.55       117
#            4       0.73      0.71      0.72       175
#            7       0.77      0.75      0.76       233
#
#     accuracy                           0.68       665
#    macro avg       0.67      0.67      0.67       665
# weighted avg       0.69      0.68      0.69       665

# %%
eclf2 = VotingClassifier(estimators=[('svmA',gridA), ('svmB', gridB)], voting='soft')

# %%
# fitting the model for grid search 
eclf2.fit(Xm_train, ym_train)
# Out:
# Fitting 3 folds for each of 6 candidates, totalling 18 fits
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.571, total= 4.6min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.6min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.561, total= 4.3min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  8.9min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.570, total= 4.7min
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.571, total= 4.7min
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.561, total= 4.3min
# [CV] C=0.1, gamma=0.1, kernel=linear .................................
# [CV] ..... C=0.1, gamma=0.1, kernel=linear, score=0.570, total= 4.6min
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.571, total= 4.5min
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.561, total= 4.3min
# [CV] C=0.1, gamma=0.01, kernel=linear ................................
# [CV] .... C=0.1, gamma=0.01, kernel=linear, score=0.570, total= 4.6min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.580, total= 5.1min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.564, total= 4.4min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.577, total= 4.8min
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.580, total= 5.0min
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.564, total= 4.4min
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.577, total= 4.8min
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.580, total= 5.1min
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.564, total= 4.5min
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.577, total= 4.8min
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 83.6min finished
# /opt/conda/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.571, total= 4.5min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  4.5min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.561, total= 4.3min
# [CV] C=0.1, gamma=1, kernel=linear ...................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  8.9min remaining:    0.0s
# [CV] ....... C=0.1, gamma=1, kernel=linear, score=0.570, total= 4.7min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.580, total= 5.1min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.564, total= 4.4min
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.577, total= 4.8min
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed: 27.8min finished
# VotingClassifier(estimators=[('svmA',
#                               GridSearchCV(cv='warn',
#                                            error_score='raise-deprecating',
#                                            estimator=SVC(C=1.0, cache_size=200,
#                                                          class_weight=None,
#                                                          coef0=0.0,
#                                                          decision_function_shape='ovr',
#                                                          degree=3,
#                                                          gamma='auto_deprecated',
#                                                          kernel='rbf',
#                                                          max_iter=-1,
#                                                          probability=True,
#                                                          random_state=None,
#                                                          shrinking=True,
#                                                          tol=0.001,
#                                                          verbose=False),
#                                            iid='warn', n_jobs=None,
#                                            param_gri...
#                                                          gamma='auto_deprecated',
#                                                          kernel='rbf',
#                                                          max_iter=-1,
#                                                          probability=True,
#                                                          random_state=None,
#                                                          shrinking=True,
#                                                          tol=0.001,
#                                                          verbose=False),
#                                            iid='warn', n_jobs=None,
#                                            param_grid={'C': [0.1, 1],
#                                                        'gamma': [1],
#                                                        'kernel': ['linear']},
#                                            pre_dispatch='2*n_jobs', refit=True,
#                                            return_train_score=False,
#                                            scoring=None, verbose=3))],
#                  flatten_transform=True, n_jobs=None, voting='soft',
#                  weights=None)

# %%
#eclf2.probability = True

# %%
ym_pred=eclf2.predict(Xm_test)

# %%
print(classification_report(ym_test, ym_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.54      0.55       142
#            2       0.54      0.16      0.25       117
#            3       0.29      0.07      0.12        27
#            4       0.61      0.75      0.67       170
#            5       0.52      0.22      0.31        50
#            6       0.82      0.52      0.64        61
#            7       0.60      0.90      0.72       250
#            8       0.50      0.40      0.44         5
#            9       1.00      0.56      0.71         9
#
#     accuracy                           0.60       831
#    macro avg       0.60      0.46      0.49       831
# weighted avg       0.59      0.60      0.56       831

# %%
for i in range(1,9):
    print("Before SMOTE, counts of label {}: {}".format(i,sum(ym_train == i))) 
 
# apply near miss 
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=2) 
  
X_train_miss, y_train_miss = sm.fit_sample(Xm_train, ym_train.ravel()) 
  
print('After SMOTE, the shape of train_X:{}'.format(X_train_miss.shape)) 
print('After SMOTE, the shape of train_y: {} \n'.format(y_train_miss.shape)) 

for i in range(1,9):
    print("After SMOTE, counts of label {}: {}".format(i,sum(y_train_miss == i)))
# Out:
# Before SMOTE, counts of label 1: 426
# Before SMOTE, counts of label 2: 335
# Before SMOTE, counts of label 3: 62
# Before SMOTE, counts of label 4: 516
# Before SMOTE, counts of label 5: 192
# Before SMOTE, counts of label 6: 214
# Before SMOTE, counts of label 7: 703
# Before SMOTE, counts of label 8: 14
# After SMOTE, the shape of train_X:(6327, 158717)
# After SMOTE, the shape of train_y: (6327,)
#
# After SMOTE, counts of label 1: 703
# After SMOTE, counts of label 2: 703
# After SMOTE, counts of label 3: 703
# After SMOTE, counts of label 4: 703
# After SMOTE, counts of label 5: 703
# After SMOTE, counts of label 6: 703
# After SMOTE, counts of label 7: 703
# After SMOTE, counts of label 8: 703

# %%
#Hyperparameter tuning for Random Forest

# %% [markdown]
# alpha = [100,200]
#          #500,1000,2000]
# max_depth = [5, 10]
# val_log_loss_array = []
# for i in alpha:
#     for j in max_depth:
#         print("for n_estimators =", i,"and max depth = ", j)
#         clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42)
#         clf.fit(X_train_miss, y_train_miss)
#         calib_clf = CalibratedClassifierCV(clf, method="sigmoid")
#         calib_clf.fit(X_train_miss, y_train_miss)
#         calib_clf_probs = calib_clf.predict_proba(X_test)
#         val_log_loss_array.append(log_loss(y_test,calib_clf_probs, labels=clf.classes_, eps=1e-15))
#         print("Log Loss :",log_loss(y_test,calib_clf_probs))
#
# best_alpha = np.argmin(val_log_loss_array)
# clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42)
# clf.fit(X_train_miss,y_train_miss)
# calib_clf = CalibratedClassifierCV(clf, method="sigmoid")
# calib_clf.fit(X_train_miss, y_train_miss)

# %%
ran_clf=RandomForestClassifier(bootstrap=True,
                                                             class_weight=None,
                                                             criterion='gini',
                                                             max_depth=10,
                                                             max_features='auto',
                                                             max_leaf_nodes=None,
                                                             min_impurity_decrease=0.0,
                                                             min_impurity_split=None,
                                                             min_samples_leaf=1,
                                                             min_samples_split=2,
                                                             min_weight_fraction_leaf=0.0,
                                                             n_estimators=200,
                                                             n_jobs=None,
                                                             oob_score=False,
                                                             random_state=42,
                                                             verbose=0,
                                                             warm_start=False)

# %%
ran_clf.fit(X_train_miss,y_train_miss)
y_pred=ran_clf.predict(Xm_test)
print(classification_report(ym_test,ym_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.56      0.54      0.55       142
#            2       0.54      0.16      0.25       117
#            3       0.29      0.07      0.12        27
#            4       0.61      0.75      0.67       170
#            5       0.52      0.22      0.31        50
#            6       0.82      0.52      0.64        61
#            7       0.60      0.90      0.72       250
#            8       0.50      0.40      0.44         5
#            9       1.00      0.56      0.71         9
#
#     accuracy                           0.60       831
#    macro avg       0.60      0.46      0.49       831
# weighted avg       0.59      0.60      0.56       831

# %%
from sklearn import svm

# %%
voting_clf = VotingClassifier([('svc', svm.SVC(probability=True)),
                            ('nsb', MultinomialNB()),
                            ('rfor', RandomForestClassifier())],voting='soft')

# %%
voting_clf.fit(X_train_miss, y_train_miss)
# Out:
# /opt/conda/lib/python3.6/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /opt/conda/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# VotingClassifier(estimators=[('svc',
#                               SVC(C=1.0, cache_size=200, class_weight=None,
#                                   coef0=0.0, decision_function_shape='ovr',
#                                   degree=3, gamma='auto_deprecated',
#                                   kernel='rbf', max_iter=-1, probability=True,
#                                   random_state=None, shrinking=True, tol=0.001,
#                                   verbose=False)),
#                              ('nsb',
#                               MultinomialNB(alpha=1.0, class_prior=None,
#                                             fit_prior=True)),
#                              ('rfor',
#                               RandomForestClassifier(b...
#                                                      class_weight=None,
#                                                      criterion='gini',
#                                                      max_depth=None,
#                                                      max_features='auto',
#                                                      max_leaf_nodes=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=1,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators='warn',
#                                                      n_jobs=None,
#                                                      oob_score=False,
#                                                      random_state=None,
#                                                      verbose=0,
#                                                      warm_start=False))],
#                  flatten_transform=True, n_jobs=None, voting='soft',
#                  weights=None)

# %%
y_pred_class=voting_clf.predict(Xm_test)
classification_report(ym_test, y_pred_class)
# Out:
# '              precision    recall  f1-score   support\n\n           1       0.53      0.63      0.58       142\n           2       0.50      0.52      0.51       117\n           3       0.48      0.56      0.52        27\n           4       0.76      0.59      0.66       170\n           5       0.35      0.46      0.40        50\n           6       0.79      0.69      0.74        61\n           7       0.72      0.71      0.72       250\n           8       1.00      0.40      0.57         5\n           9       0.69      1.00      0.82         9\n\n    accuracy                           0.62       831\n   macro avg       0.65      0.62      0.61       831\nweighted avg       0.64      0.62      0.63       831\n'

# %%
print(accuracy_score(ym_test,y_pred_class))

# %%
y_pred_class
# Out:
# array([1, 7, 1, 7, 4, 1, 1, 2, 4, 1, 4, 1, 6, 1, 4, 1, 4, 7, 7, 1, 7, 3,
#        5, 1, 4, 7, 7, 7, 5, 7, 1, 4, 7, 9, 7, 7, 4, 3, 2, 2, 1, 7, 7, 4,
#        1, 7, 2, 7, 1, 3, 5, 4, 1, 7, 7, 1, 4, 4, 4, 5, 2, 6, 3, 7, 2, 7,
#        4, 5, 4, 7, 1, 7, 7, 7, 1, 1, 7, 7, 7, 1, 6, 2, 4, 1, 2, 1, 4, 4,
#        1, 7, 7, 7, 7, 5, 1, 2, 7, 2, 4, 4, 2, 6, 5, 1, 4, 7, 1, 5, 1, 7,
#        6, 4, 2, 7, 7, 5, 7, 4, 1, 6, 7, 7, 2, 5, 1, 2, 5, 7, 3, 7, 4, 1,
#        1, 7, 6, 7, 4, 2, 4, 4, 2, 7, 1, 7, 2, 2, 9, 2, 2, 7, 4, 7, 1, 7,
#        6, 2, 7, 5, 1, 9, 4, 7, 2, 7, 6, 5, 7, 7, 1, 6, 3, 6, 7, 2, 1, 7,
#        7, 2, 5, 7, 2, 4, 5, 7, 2, 4, 2, 7, 1, 1, 1, 2, 7, 5, 5, 4, 5, 3,
#        5, 4, 1, 2, 7, 1, 6, 7, 7, 8, 9, 7, 1, 1, 2, 7, 3, 7, 4, 7, 7, 6,
#        1, 7, 7, 7, 6, 5, 7, 7, 7, 1, 1, 4, 7, 4, 5, 3, 2, 4, 4, 2, 7, 2,
#        5, 7, 7, 5, 7, 7, 9, 4, 1, 7, 4, 7, 7, 4, 7, 5, 1, 7, 7, 1, 1, 2,
#        1, 7, 7, 7, 9, 7, 7, 7, 4, 6, 4, 2, 2, 7, 7, 1, 5, 4, 5, 5, 1, 1,
#        7, 6, 7, 1, 1, 5, 1, 9, 1, 1, 2, 2, 4, 6, 7, 1, 7, 1, 7, 2, 7, 4,
#        6, 2, 4, 7, 7, 6, 4, 7, 2, 7, 7, 4, 6, 4, 7, 5, 1, 7, 5, 2, 1, 7,
#        3, 7, 4, 7, 5, 7, 1, 7, 7, 1, 4, 4, 5, 2, 6, 4, 1, 7, 2, 2, 9, 7,
#        1, 7, 7, 7, 7, 7, 2, 1, 4, 1, 6, 4, 4, 4, 1, 4, 4, 7, 3, 7, 7, 2,
#        6, 7, 7, 7, 1, 1, 4, 7, 2, 1, 1, 1, 7, 1, 7, 4, 2, 2, 7, 2, 6, 1,
#        7, 1, 4, 2, 7, 6, 5, 7, 7, 7, 5, 7, 1, 7, 5, 2, 5, 4, 7, 5, 4, 1,
#        7, 1, 2, 4, 6, 7, 4, 7, 7, 1, 1, 1, 2, 2, 7, 3, 1, 7, 7, 4, 7, 3,
#        6, 2, 2, 1, 6, 7, 4, 7, 4, 6, 2, 1, 4, 1, 5, 4, 2, 1, 1, 2, 1, 4,
#        1, 1, 7, 2, 4, 7, 6, 4, 6, 4, 1, 2, 1, 7, 1, 4, 1, 4, 4, 2, 3, 2,
#        2, 2, 4, 2, 1, 5, 4, 2, 7, 2, 7, 5, 7, 7, 1, 7, 3, 1, 4, 4, 7, 1,
#        9, 5, 5, 4, 4, 1, 1, 7, 5, 3, 5, 7, 4, 2, 4, 7, 7, 7, 6, 9, 1, 4,
#        4, 7, 1, 2, 4, 2, 7, 1, 3, 3, 7, 5, 4, 7, 7, 1, 7, 7, 3, 7, 4, 4,
#        1, 1, 4, 7, 5, 3, 6, 5, 5, 2, 6, 1, 2, 2, 4, 6, 7, 5, 7, 1, 5, 4,
#        7, 2, 4, 1, 5, 2, 4, 2, 1, 1, 6, 2, 2, 5, 4, 1, 6, 7, 2, 7, 7, 1,
#        1, 2, 2, 7, 3, 4, 4, 2, 2, 4, 4, 7, 7, 1, 7, 4, 7, 7, 1, 7, 4, 7,
#        7, 6, 6, 1, 1, 2, 7, 9, 1, 2, 7, 6, 7, 5, 1, 7, 3, 1, 7, 7, 4, 7,
#        2, 7, 2, 7, 4, 7, 6, 2, 1, 3, 1, 2, 4, 7, 1, 2, 2, 2, 1, 2, 4, 1,
#        7, 7, 5, 7, 2, 4, 7, 7, 3, 4, 1, 3, 7, 7, 7, 9, 5, 6, 7, 1, 6, 5,
#        7, 7, 7, 7, 4, 4, 1, 6, 2, 2, 3, 4, 5, 2, 2, 2, 7, 1, 1, 4, 1, 4,
#        1, 1, 6, 6, 7, 3, 7, 7, 4, 2, 2, 1, 3, 7, 7, 1, 1, 2, 4, 7, 7, 7,
#        7, 1, 1, 4, 4, 2, 7, 1, 7, 2, 7, 5, 9, 1, 7, 7, 6, 7, 6, 1, 1, 5,
#        7, 1, 3, 1, 1, 7, 2, 2, 1, 2, 4, 4, 1, 5, 1, 4, 6, 3, 1, 1, 5, 7,
#        1, 2, 3, 1, 4, 4, 7, 7, 6, 7, 1, 1, 8, 2, 1, 7, 2, 7, 2, 5, 7, 7,
#        6, 7, 2, 2, 1, 2, 4, 4, 5, 5, 1, 5, 6, 7, 1, 7, 4, 1, 1, 1, 7, 7,
#        1, 6, 7, 7, 2, 2, 4, 7, 5, 4, 2, 7, 7, 1, 2, 7, 4])

# %% [markdown]
#  **Using TF-IDF**

# %% [markdown]
# tf=TfidfVectorizer()
# text_tf= tf.fit_transform(training_merge['Text'])

# %% [markdown]
# text_tf

# %% [markdown]
# X_train, X_test, y_train, y_test = train_test_split(
#     text_tf, training_merge['Class'], test_size=0.3, random_state=123)

# %% [markdown]
# X_train.shape

# %% [markdown]
# from sklearn.naive_bayes import MultinomialNB
# from sklearn import metrics
# from sklearn.metrics import confusion_matrix, classification_report
# # Model Generation Using Multinomial Naive Bayes
# clf = MultinomialNB().fit(X_train, y_train)
# predicted= clf.predict(X_test)
# print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# print(classification_report(y_test,predicted))

# %% [markdown]
# #Trying to handle imbalanced data

# %% [markdown]
# #SMOTE

# %% [markdown]
# from sklearn.naive_bayes import MultinomialNB
# from sklearn import metrics
# from sklearn.metrics import confusion_matrix, classification_report
# # Model Generation Using Multinomial Naive Bayes
# clf = MultinomialNB().fit(X_train_miss, y_train_miss)
# predicted= clf.predict(X_test)
# print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# print(classification_report(y_test,predicted))

# %% [markdown]
# #USING SMOTE

# %% [markdown]
# for i in range(1,9):
#     print("Before SMOTE, counts of label {}: {}".format(i,sum(y_train == i)))
#
# # apply near miss
# from imblearn.over_sampling import SMOTE
# sm = SMOTE(random_state=2)
#
# X_train_miss, y_train_miss = sm.fit_sample(X_train, y_train.ravel())
#
# print('After SMOTE, the shape of train_X:{}'.format(X_train_miss.shape))
# print('After SMOTE, the shape of train_y: {} \n'.format(y_train_miss.shape))
#
# for i in range(1,9):
#     print("After SMOTE, counts of label {}: {}".format(i,sum(y_train_miss == i)))

# %% [markdown]
# from sklearn.naive_bayes import MultinomialNB
# from sklearn import metrics
# from sklearn.metrics import confusion_matrix, classification_report
# # Model Generation Using Multinomial Naive Bayes
# clf = MultinomialNB().fit(X_train_miss, y_train_miss)
# predicted= clf.predict(X_test)
# print("MultinomialNB Accuracy:",metrics.accuracy_score(y_test, predicted))
# print(classification_report(y_test,predicted))

# %% [markdown]
# #ACCURACY DOES BETTER WITH SMOTE SO WE WILL USE SMOTE

# %% [markdown]
# # Let's run Linear SVM model using the selected variables
# from sklearn import metrics
# from sklearn import svm
# from sklearn.metrics import classification_report
# svc_model=svm.LinearSVC()
# svc_model.fit(X_train_miss,y_train_miss)
#
# #predicting the Test data using our trained Linear SVM model
# y_pred_class = svc_model.predict(X_test)
#
# print(classification_report(y_test, y_pred_class))
